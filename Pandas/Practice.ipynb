# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('melb_data.csv')

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_pm5550000 = df[df['Price'] > 5550000]

# %%
df_pm1000000
# Out:
#        Unnamed: 0       Suburb         Address  Rooms Type      Price Method  \
# 4551         5867          Kew      7 Wimba Av      5    h  6240000.0      S
# 4599         5937          Kew     15 Barry St      6    h  6500000.0      S
# 7184         9264  South Yarra     18 Avoca St      4    h  5700000.0      S
# 8143        10451       Toorak    17 Albany Rd      3    h  6250000.0      S
# 9589        12316     Brighton   161 Church St      5    h  5800000.0     PI
# 9754        12539   Canterbury  49 Mangarra Rd      5    h  8000000.0     VB
# 11033       14179       Toorak    13 Toorak Av      4    h  5733000.0      S
# 11765       15130  Middle Park     204 Page St      6    h  5600000.0     PI
# 12219       15696     Hawthorn    49 Lisson Gr      4    h  7650000.0      S
# 12447       16003       Toorak      21 Iona Av      4    h  6460000.0      S
# 12481       16048     Armadale    9 Alleyne Av      5    h  5925000.0      S
# ...

# %%
df.groupby('Method')['Distance'].mean()
# Out:
# Method
# PI     9.656418
# S     10.718233
# SA    12.369531
# SP    10.612516
# VB     8.550295
# Name: Distance, dtype: float64

# %%
df['Method'].value_counts()
# Out:
# S     12034
# SP     2349
# PI     2189
# VB     1696
# SA      128
# Name: Method, dtype: int64

# %%
df['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
df['MT'] = df['Method'] + ' _ ' + df['Type']
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %%
df.groupby('Method')['Distance'].aggregate(lambda x: x.sum() / len(x))
# Out:
# Method
# PI     9.656418
# S     10.717343
# SA    12.369531
# SP    10.612516
# VB     8.550295
# Name: Distance, dtype: float64

# %%
animals = ['Bear', 'Mosse', 'Lion']

# %%
p_animals = pd.Series(animals)
p_animals
# Out:
# 0     Bear
# 1    Mosse
# 2     Lion
# dtype: object

# %%
animals = {
    'n1':'Bear',
    'n2':'Moose'
}

# %%
p_animals = pd.Series(animals)
p_animals
# Out:
# n1     Bear
# n2    Moose
# dtype: object

# %%
p_animals.index
# Out:
# Index(['n1', 'n2'], dtype='object')

# %%
df.loc[56:123, ['Method']]
# Out:
#     Method
# 56       S
# 57       S
# 58      VB
# 59      VB
# 60      VB
# ..     ...
# 119     PI
# 120      S
# 121      S
# 122      S
# 123      S
#
# [68 rows x 1 columns]

# %%
df.drop(5, inplace = True)

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %%
df2 = df[:]
df2
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount', 'MT'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18395.000000  18395.000000  1.839500e+04  18394.000000  18394.000000
# mean   11827.429465      2.935091  1.056704e+06     10.390415   3107.142329
# std     6800.337136      0.958203  6.419385e+05      6.008931     95.003116
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5937.500000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11821.000000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.500000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14926.000000  14924.000000  14819.000000   13602.000000   7762.000000
# mean       2.913105      1.538529      1.615629     558.144096    151.220219
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18395 entries, 0 to 18395
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18395 non-null  int64
#  1   Suburb         18395 non-null  object
#  2   Address        18395 non-null  object
#  3   Rooms          18395 non-null  int64
#  4   Type           18395 non-null  object
#  5   Price          18395 non-null  float64
#  6   Method         18395 non-null  object
#  7   SellerG        18395 non-null  object
#  8   Date           18395 non-null  object
#  9   Distance       18394 non-null  float64
#  10  Postcode       18394 non-null  float64
#  11  Bedroom2       14926 non-null  float64
#  12  Bathroom       14924 non-null  float64
#  13  Car            14819 non-null  float64
#  14  Landsize       13602 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
# ...

# %%
df[df['Distance'] > 40]
# Out:
#        Unnamed: 0          Suburb             Address  Rooms Type      Price  \
# 11143       14313     Clyde North     11 Riverbank Cl      4    h   689000.0
# 11205       14389        Gisborne         3 Sansom St      4    h   521000.0
# 11234       14426     Healesville    15A Westmount Rd      3    h   650000.0
# 11820       15198        Pakenham        31 Azalea Av      4    h   510000.0
# 12181       15645        Gisborne      60 Hamilton St      3    h   540000.0
# 12266       15761      Langwarrin  6/30 Warrenwood Pl      2    u   400000.0
# 12793       16473        Pakenham    69 Willowtree Dr      4    h   410500.0
# 12831       16518  Riddells Creek      53 Bluegum Cct      4    h   817000.0
# 12832       16519  Riddells Creek          2 Dwyer Ct      4    h   967500.0
# 13063       16818     Clyde North      15 Palomino Av      4    h   635000.0
# 13166       16946        Gisborne      4/7 Francis Cr      3    h   470000.0
# ...
